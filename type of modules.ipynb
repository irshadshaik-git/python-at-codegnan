# %%
import math
import random 
import os
import sys

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import math
print(math.ceil(4.25))  # it returns the upperbound integer value
print(math.floor(4.25)) # it returns the lowerbound integer value
print(math.factorial(5)) # it returns the Factorial of the number
print(math.gcd(10,6,4))  # it returns the Gratest common Devisor
print(math.lcm(10,6,4))  #it returns the lest common <Multiplier
print(math.pow(10,3))   # it returns the float type of  b raise to q
print(math.sqrt(9))     # it returns the squereroot value of a number
print(math.log10(4)) # to find the log10 value
# Out:
# 5
# 4
# 120
# 2
# 60
# 1000.0
# 3.0
# 0.6020599913279624

# %%
import random 
print(random.random())  # This fuction Generates the random number between 0 to 
print(random.randint(1,6)) # This Funstions  generates the random numbers between a range 
print(random.randint(1000,9999)) # 4 digits OTP generator
print(random.choice(['a',1,2,3,4,5,6,7,8,9,'j','q','k'])) # this function is used for random of the sequences
print(random.choices(['a',1,2,3,4,5,6,7,8,9,'j','q','k'],k=3))
arr = ['a',1,2,3,4,5,6,7,8,9,'j','q','k']
random.shuffle(arr)
print(arr)
# Out:
# 0.6340107326324751
# 1
# 1430
# 4
# [7, 'q', 6]
# [1, 7, 9, 8, 2, 'j', 'a', 5, 6, 'k', 4, 'q', 3]

# %%
import random
rools=0
count=0
print("welcome to the who will reach Top in less steps game")
while True:
    input(" To Trow a dice, plz click enter button")
    face_val = random.randint(1,6)
    if count + face_val <= 100:
        count +=face_val

    rools += 1
    if count == 100:
        print(f"You reach the TOP for {rools} chances")
        brak
        print(f"your dice value:{face_val}")
    print(f"Your  are at{count} positoion in {rools} chances")
    print("*" * 100)
# Out:
# welcome to the who will reach Top in less steps game
#  To Trow a dice, plz click enter button
# Your  are at5 positoion in 1 chances
# ****************************************************************************************************
#  To Trow a dice, plz click enter button
# Your  are at8 positoion in 2 chances
# ****************************************************************************************************
#  To Trow a dice, plz click enter button
# Your  are at9 positoion in 3 chances
# ****************************************************************************************************
#  To Trow a dice, plz click enter button
# Your  are at12 positoion in 4 chances
# ****************************************************************************************************
#  To Trow a dice, plz click enter button
# Your  are at16 positoion in 5 chances
# ****************************************************************************************************
# ...

# %%
import os
print(os.getcwd())# it returns the current working directory
if not os.path.exists("a"): # os.path.exists(path): it returns True if path exits
    os.mkdir("a") # this function creats new empty directory
os.chdir('modules')
print(os.getcwd())
print(os.listdir("."))
# Out:
# C:\Users\gousi\Desktop\python code
# C:\Users\gousi\Desktop\python code\modules
# ['addition.py', 'division.py', 'multiplication.py', 'small_calculater.py', 'subtraction.py', '__pycache__']
