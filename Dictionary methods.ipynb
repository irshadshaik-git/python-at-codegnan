# %% [markdown]
# # Dictionary Characteristics

# %%
# dictionry orderd collection
details={"name": "babu","course":"python","Batch":57,"Age":20}
print(details)
# Out:
# {'name': 'babu', 'course': 'python', 'Batch': 57, 'Age': 20}

# %%
#Dictionary value access by using keys
#Update dictionary values
#adding new items to dictionary
details={"name": "babu","course":"python","Batch":57,"Age":20}
print(details['course'])
#print(details['location'])# keyErroe:'Location'
#updating dictionary values
details['age']=25
print(details['age'])
#addining new items
details['location']="hyderbad"
print(details)
# Out:
# python
# 25
# {'name': 'babu', 'course': 'python', 'Batch': 57, 'Age': 20, 'age': 25, 'location': 'hyderbad'}

# %%
#dictionary keys are uniue
details={"Age":22,"name": "babu","course":"python","Batch":57,"Age":20}
print(details)
# Out:
# {'Age': 20, 'name': 'babu', 'course': 'python', 'Batch': 57}

# %%
#list can't be used ad dictionary key
#dictionary keys are uniue
details={"Age":22,"name": "babu","course":"python",[1,2,3]:45,"Batch":57,"Age":20}
print(details)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 #list can't be used ad dictionary key
#       2 #dictionary keys are uniue
# ----> 3 details={"Age":22,"name": "babu","course":"python",[1,2,3]:45,"Batch":57,"Age":20}
#       4 print(details)
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %% [markdown]
# ### Dictionary Methods

# %% [markdown]
# - get(key,default_value):It returns the value if key is dictionary,otherwise it returns defaul value

# %%
# dictionary key ate uniue
details={"Age":22,"name": "babu","course":"python","Batch":57,"Age":20}
print(details['name'])
#print(details['marks']) # This abe raises KeyError
print(details.get('name'))
print(details.get('marks'))#get Method bydefault it returns None if key not exists in details
print(details.get('marks',"marks are not available"))#it returns defualt value ,because
# Out:
# babu
# babu
# marks are not available

# %% [markdown]
# - update(new_dictionary) : This methods updates the values if new_dictionary keys already exits in Dictionary,otherwise it adds new items to dictionary

# %%
details={"Age":22,"name": "babu","course":"python","Batch":57}
details.update({'batch':58,'course':'java',"Location":"hyd"})
print(details)
# Out:
# {'Age': 22, 'name': 'babu', 'course': 'java', 'Batch': 57, 'batch': 58, 'Location': 'hyd'}

# %% [markdown]
# - Keys(): This methods returns the list dictionary Keys
# - value():This methods returns the list dictionary values
# - items():This methods returns the list  of Tuple of key_value pairs

# %%
details={'Age': 22, 'name': 'babu', 'course': 'java', 'Batch': 57, 'batch': 58, 'Location': 'hyd'}
keys=details.keys()
print(type(keys))
print(keys)
print(details.values())
print(details.items())
# Out:
# <class 'dict_keys'>
# dict_keys(['Age', 'name', 'course', 'Batch', 'batch', 'Location'])
# dict_values([22, 'babu', 'java', 57, 58, 'hyd'])
# dict_items([('Age', 22), ('name', 'babu'), ('course', 'java'), ('Batch', 57), ('batch', 58), ('Location', 'hyd')])

# %% [markdown]
# - popitem(): it return and removes the list item as tuple
# - pop(key): this method removes the specified key item and return the specified key's
#   value,otherwise 'KeyError'

# %%
details={'Age': 22, 'name': 'babu', 'course': 'java', 'Batch': 57, 'batch': 58, 'Location': 'hyd'}
item=details.popitem()
print(item)
print(details)
val= details.pop('name')
print(val)
print(details)
# Out:
# ('Location', 'hyd')
# {'Age': 22, 'name': 'babu', 'course': 'java', 'Batch': 57, 'batch': 58}
# babu
# {'Age': 22, 'course': 'java', 'Batch': 57, 'batch': 58}

# %%
# Membership
# it checks with dictionary keys
details={'Age': 22, 'name': 'babu', 'course': 'java', 'Batch': 57, 'batch': 58, 'Location': 'hyd'}
print('babu' in details)
print('name' in details)
# Out:
# False
# True

# %%
# Library Management System using Functions (def)

books = []

def add_book():
    book_id = input("Enter Book ID: ")
    title = input("Enter Book Title: ")
    author = input("Enter Author Name: ")
    quantity = int(input("Enter Quantity: "))

    book = {
        "ID": book_id,
        "Title": title,
        "Author": author,
        "Quantity": quantity
    }

    books.append(book)
    print("Book added successfully!")

def view_books():
    if len(books) == 0:
        print("No books available.")
    else:
        print("\n----- Book List -----")
        for book in books:
            print("Book ID :", book["ID"])
            print("Title   :", book["Title"])
            print("Author  :", book["Author"])
            print("Quantity:", book["Quantity"])
            print("---------------------")

def search_book():
    title = input("Enter Book Title: ")

    for book in books:
        if book["Title"].lower() == title.lower():
            print("\nBook Found")
            print("Book ID :", book["ID"])
            print("Title   :", book["Title"])
            print("Author  :", book["Author"])
            print("Quantity:", book["Quantity"])
            return

    print("Book not found.")

def delete_book():
    book_id = input("Enter Book ID to delete: ")

    for book in books:
        if book["ID"] == book_id:
            books.remove(book)
            print("Book deleted successfully!")
            return

    print("Book not found.")

def menu():
    while True:
        print("\n===== LIBRARY MANAGEMENT SYSTEM =====")
        print("1. Add Book")
        print("2. View Books")
        print("3. Search Book")
        print("4. Delete Book")
        print("5. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            add_book()
        elif choice == "2":
            view_books()
        elif choice == "3":
            search_book()
        elif choice == "4":
            delete_book()
        elif choice == "5":
            print("Thank you!")
            break
        else:
            print("Invalid choice.")

# Start the program
menu()
# Out:
# ===== LIBRARY MANAGEMENT SYSTEM =====
# 1. Add Book
# 2. View Books
# 3. Search Book
# 4. Delete Book
# 5. Exit
# Enter your choice:  2
# No books available.
#
# ===== LIBRARY MANAGEMENT SYSTEM =====
# 1. Add Book
# 2. View Books
# 3. Search Book
# 4. Delete Book
# 5. Exit
# Enter your choice:  1
# Enter Book ID:  123
# Enter Book Title:  secrate of life
# Enter Author Name:  eeshu
# Enter Quantity:  4
# Book added successfully!
#
# ===== LIBRARY MANAGEMENT SYSTEM =====
# 1. Add Book
# 2. View Books
# 3. Search Book
# 4. Delete Book
# 5. Exit
# Enter your choice:  2
# ----- Book List -----
# Book ID : 123
# Title   : secrate of life
# Author  : eeshu
# Quantity: 4
# ---------------------
#
# ===== LIBRARY MANAGEMENT SYSTEM =====
# 1. Add Book
# 2. View Books
# 3. Search Book
# 4. Delete Book
# 5. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 84
# ...
