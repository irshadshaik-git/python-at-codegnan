# %%
# check weather the number is +ve even,-ve even,+ve odd,-ve odd,Zero nestead if condition
num=int(input())
if num>=0:
    if(num%2==0):
        print("positive even")
    else:
        print("positive odd")
else:
    if num%2==0:
        print("negitive even")
    else:
        print("negitive odd")
# Out:
#  -3
# negitive odd

# %%
#check weather the following nember in elif
num=int(input())
if num%2==0  and num>=0:
    print("positive even")
elif num%2==0 and num>=1:
    print("positve odd")
elif num%2==0 and num<0:
    print("-ve even")

else:
    print("-ve odd")
# Out:
#  -36546
# -ve even

# %%
n= int(input())
#+ve even and not
if n>=0 and n%2==0:
    print(f'{n}+ve even')
elif n>=0:
    print(f'{n}-+e odd')
#-ve even or not
elif n%2==0:
    print(f'{n}-ve even')
else:
    print(f'{n}-ve odd')
# Out:
#  -33
# -33-ve odd

# %%
#find the smallest number using the 3 numbers
num1=int(input())
num2=int(input())
num3=int(input())
if num1<num2 and num1<num3:
    print("num1")
elif num2<num3 and num2<num1:
    print("num2")
elif num3<num1 and num3<num2:
    print("num3")
else:
    print()
# Out:
#  22
#  40
#  800
# num1

# %%
a=int(input())
b=int(input())
c=int(input())
if a>b and a>c:
    print("a")
elif b>c:
    print("b")
else:
    print("c")
# Out:
#  10
#  20
#  30
# c

# %%
a,b,c=map(int,input().split())
if a>b and b>c and c>a:
    if a>b:
        print(a)
    else :
        print(b)
else:
    if c>a:
        print(c)
    else:
        print("nothing")
# Out:
#  45 45 65
# 65

# %%
a,b,c=map(int,input().split())
if a>b:
    if a>c:
        print(a)
    else :
        print(b)
else:
    if c>b:
        print(c)
    else:
        print("nothing")
# Out:
#  13212 2233332 1
# nothing
