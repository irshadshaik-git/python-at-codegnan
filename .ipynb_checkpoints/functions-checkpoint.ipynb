# %%
# Type of fuction based on parameters and return value
#4. With patameters and with return
# function defination block
def addition(x:int,y:int)->int:
    c=x+y
    return c
#function calling block
a,b = 10,20
res = addition(a,b)
print(res)
# Out:
# 30
