# %%
#immutable 
# after operation it doesn't change the length of object and doesn't change remining elelment position
t=(1,2,3,4,[10,20,30],20)
t[4].append(100)
print(t)
# Out:
# (1, 2, 3, 4, [10, 20, 30, 100], 20)

# %%
# empty tuple representation
# single element representation
t1=()
t2=tuple()
print(type(t1),type(t2))
# Out:
# <class 'tuple'> <class 'tuple'>

# %%
# single element representation
t1=(10)
t2=(10,)
l1=[10]
print(type(t1),type(l1),type(t2))
# Out:
# <class 'int'> <class 'list'> <class 'tuple'>
