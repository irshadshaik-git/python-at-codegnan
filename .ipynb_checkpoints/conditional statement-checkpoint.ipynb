# %%
#check weather the number is divisable by 3 or NOT
num = int(input())
if num%3==0:
    print(f'{num} is divisable by 3')
else:
    print(f'{num} is not divisable by 3')
# Out:
#  6
# 6 is divisable by 3

# %%
#check weather the number is divisable by 3 and 5 or NOT
num = int(input())
if(num%3==0 and num%5==0):
    print(f'{num} is divisable by 3 and 5')
else:
    print(f'{num} is not divisable by 3 and 5')
# Out:
#  3
# 3 is not divisable by 3 and 5

# %%
#check weather the number is divisable by 3 or 5
num = int(input())
if(num%3==0 or num%5==0):
    print(f'{num} is divisable by 3 and 5')
else:
    print(f'{num} is not divisable by 3 and 5')
# Out:
#  11
# 11 is not divisable by 3 and 5

# %%
# check weather the folloeing number is even or odd
num=int(input())
if num%2==0:
    print(f'{num} its even')
else:
    print(f'{num} its odd')
# Out:
#  5
# 5 its odd

# %%
# generate total bill if total bill morethen 500 then give 10% discount otherwise 0% discount
num=int(input())
if num > 500:
    discount = num*0.1
    print(f'{num-discount} after given of  10% discount')
else:
    print(f'{num} after given of  0% discount')
# Out:
#  700
# 630.0 after given of  10% discount

# %%
# check weATHER the product stock is avilable or not(read product name and stock)
product=input()
stock=int(input())
if stock > 0:
    print(f"curently {product}:{stock} items avilable")
else:
    print(f'curently {product}out off stock')
# Out:
#  laddu
#  56695
# curently laddu:56695 items avilable

# %%
# 5th
products={'pen':5, 'book':20, 'pencile':3}
item=input()
quantity=int(input())
if item in products:
    total_amount = products.get(item)*quantity
    print(f'total amount of {quantity} {item} is: {total_amount}')
else:
    print(f"{item} not avaliable")
# Out:
#  pen
#  5
# total amount of 5 pen is: 25

# %%
##### check weather the number is positive ,negitive or ZERO
num = int(input())
if num > 0:
    print(f'{num} is +ve')
elif num<0:
    print(f'{num} is -ve')
else:
    print(f'{num} is ZERO')
# Out:
#  0
# 0 is ZERO

# %%
# divisable by 3 - Fizz
# divisable by 5 - buzz
# divisable by both - Fizzbuzz
num= int(input())
if num%5==0 and num%3==0:
    print("Fizzbuzz")
elif num%3==0:
    print("Buzz")
elif num%5==0:
     print("Fizz")
else:
    print("hero")
# Out:
#  15
# Fizzbuzz
